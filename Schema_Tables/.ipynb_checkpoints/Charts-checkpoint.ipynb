# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt

# ── Connection ──────────────────────────────────────────────
cnx = mysql.connector.connect(
    user='root',
    password='Allaberganov_1982',
    host='localhost',
    port=3306,
    database='final_project_2'
)

plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['axes.spines.top']   = False
plt.rcParams['axes.spines.right'] = False
print("Connected!")

# ════════════════════════════════════════════════════════════
# REQUIRED QUERIES (1–5)
# ════════════════════════════════════════════════════════════

# ── Query 1 — Top 20 Best-Selling Products (All Stores) ─────
q1 = """
SELECT p.name, SUM(oi.quantity) AS total_sold
FROM order_item oi
JOIN product p ON oi.productID = p.productID
GROUP BY oi.productID
ORDER BY total_sold DESC
LIMIT 20
"""
df1 = pd.read_sql(q1, cnx)

fig, ax = plt.subplots(figsize=(12, 7))
bars = ax.barh(df1['name'][::-1], df1['total_sold'][::-1], color='#185ADB', edgecolor='none')
ax.bar_label(bars, padding=4, fontsize=10)
ax.set_xlabel('Total Units Sold', fontsize=12)
ax.set_title('Q1 — Top 20 Best-Selling Products (All Stores)', fontsize=14, fontweight='bold', pad=15)
ax.set_xlim(0, df1['total_sold'].max() * 1.15)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('Q1_top20_products.png', dpi=150, bbox_inches='tight')
plt.show()
print("Q1 done\n")

# ── Query 2 — Top 5 Products by State ───────────────────────
q2 = """
SELECT bm.state, p.name, SUM(oi.quantity) AS total_sold
FROM orders o
JOIN order_item oi ON o.orderID = oi.orderID
JOIN product p ON oi.productID = p.productID
JOIN BM bm ON o.storeID = bm.storeID
GROUP BY bm.state, p.productID
ORDER BY bm.state, total_sold DESC
"""
df2 = pd.read_sql(q2, cnx)
df2_top = df2.groupby('state').head(5).reset_index(drop=True)
states = sorted(df2_top['state'].unique())

colors = ['#185ADB', '#0D9488', '#7C3AED', '#D97706', '#DC2626']
fig, axes = plt.subplots(1, len(states), figsize=(14, 5))
for i, state in enumerate(states):
    data = df2_top[df2_top['state'] == state]
    axes[i].barh(data['name'][::-1], data['total_sold'][::-1], color=colors[i], edgecolor='none')
    axes[i].set_title(state, fontsize=13, fontweight='bold', color=colors[i])
    axes[i].tick_params(axis='y', labelsize=8)
    axes[i].spines['top'].set_visible(False)
    axes[i].spines['right'].set_visible(False)
fig.suptitle('Q2 — Top 5 Products by State', fontsize=15, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('Q2_top5_by_state.png', dpi=150, bbox_inches='tight')
plt.show()
print("Q2 done\n")

# ── Query 3 — Top 5 Stores by Total Sales ───────────────────
q3 = """
SELECT o.storeID,
       COALESCE(bm.city, 'Online') AS store_name,
       SUM(op.total) AS total_sales
FROM orders o
JOIN order_payment op ON o.orderID = op.orderID
LEFT JOIN BM bm ON o.storeID = bm.storeID
WHERE YEAR(o.orderDate) = 2025
GROUP BY o.storeID
ORDER BY total_sales DESC
LIMIT 5
"""
df3 = pd.read_sql(q3, cnx)
df3['label'] = df3['store_name'] + '\n(Store ' + df3['storeID'].astype(str) + ')'

fig, ax = plt.subplots(figsize=(10, 5))
bar_colors = ['#FFC300'] + ['#185ADB'] * (len(df3) - 1)
bars = ax.bar(df3['label'], df3['total_sales'], color=bar_colors, edgecolor='none', width=0.5)
ax.bar_label(bars, fmt='$%.2f', padding=4, fontsize=10)
ax.set_ylabel('Total Sales ($)', fontsize=12)
ax.set_title('Q3 — Top 5 Stores by Total Sales (2025)', fontsize=14, fontweight='bold', pad=15)
ax.set_ylim(0, df3['total_sales'].max() * 1.2)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('Q3_top5_stores.png', dpi=150, bbox_inches='tight')
plt.show()
print("Q3 done\n")

# ── Query 4 — iPhone vs Samsung TV ──────────────────────────
q4 = """
SELECT COUNT(DISTINCT o.storeID) AS stores_iphone_outsells_tv
FROM orders o
JOIN order_item oi ON o.orderID = oi.orderID
WHERE oi.productID = 6
AND o.storeID IN (
    SELECT o2.storeID
    FROM orders o2
    JOIN order_item oi2 ON o2.orderID = oi2.orderID
    WHERE oi2.productID = 1
    GROUP BY o2.storeID
    HAVING SUM(oi2.quantity) < (
        SELECT SUM(oi3.quantity)
        FROM orders o3
        JOIN order_item oi3 ON o3.orderID = oi3.orderID
        WHERE oi3.productID = 6 AND o3.storeID = o2.storeID
    )
)
"""
df4 = pd.read_sql(q4, cnx)
result = df4['stores_iphone_outsells_tv'].values[0]
total_stores = 5

fig, ax = plt.subplots(figsize=(7, 4))
ax.barh(['Samsung TV', 'Apple iPhone 15'],
        [total_stores - result, result],
        color=['#6B7280', '#185ADB'], edgecolor='none', height=0.4)
ax.set_xlabel('Number of Stores', fontsize=12)
ax.set_title('Q4 — iPhone vs Samsung TV: Stores Where iPhone Outsells', fontsize=13, fontweight='bold', pad=15)
ax.set_xlim(0, total_stores + 0.5)
for i, v in enumerate([total_stores - result, result]):
    ax.text(v + 0.1, i, str(v), va='center', fontsize=12, fontweight='bold')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('Q4_iphone_vs_tv.png', dpi=150, bbox_inches='tight')
plt.show()
print(f"Q4 done — iPhone outsells Samsung TV in {result} out of {total_stores} stores\n")

# ── Query 5 — Top 3 Products Bought Alongside PS5 ───────────
q5 = """
SELECT p.name, SUM(oi.quantity) AS times_bought_together
FROM order_item oi
JOIN product p ON oi.productID = p.productID
WHERE oi.orderID IN (
    SELECT orderID FROM order_item WHERE productID = 5
)
AND oi.productID != 5
GROUP BY oi.productID
ORDER BY times_bought_together DESC
LIMIT 3
"""
df5 = pd.read_sql(q5, cnx)

fig, ax = plt.subplots(figsize=(7, 5))
wedges, texts, autotexts = ax.pie(
    df5['times_bought_together'],
    labels=df5['name'],
    autopct='%1.1f%%',
    colors=['#185ADB', '#0D9488', '#FFC300'],
    startangle=140,
    pctdistance=0.75,
    wedgeprops=dict(edgecolor='white', linewidth=2)
)
for t in texts: t.set_fontsize(11)
for t in autotexts: t.set_fontsize(10); t.set_fontweight('bold')
ax.set_title('Q5 — Top 3 Products Bought Alongside PS5', fontsize=13, fontweight='bold', pad=15)
plt.tight_layout()
plt.savefig('Q5_bought_with_ps5.png', dpi=150, bbox_inches='tight')
plt.show()
print("Q5 done\n")

# ════════════════════════════════════════════════════════════
# ADDITIONAL QUERIES (6–9)
# ════════════════════════════════════════════════════════════

# ── Query 6 — Revenue by Product Category ───────────────────
q6 = """
SELECT
    CASE
        WHEN e.productID IS NOT NULL THEN 'Electronics'
        WHEN a.productID IS NOT NULL THEN 'Appliances'
        WHEN t.productID IS NOT NULL THEN 'Toys'
        WHEN f.productID IS NOT NULL THEN 'Furniture'
    END AS category,
    ROUND(SUM(oi.quantity * p.price)) AS total_revenue
FROM order_item oi
JOIN product p ON oi.productID = p.productID
LEFT JOIN electronics e ON p.productID = e.productID
LEFT JOIN appliances a ON p.productID = a.productID
LEFT JOIN toys t ON p.productID = t.productID
LEFT JOIN furniture f ON p.productID = f.productID
GROUP BY category
ORDER BY total_revenue DESC
"""
df6 = pd.read_sql(q6, cnx)

fig, ax = plt.subplots(figsize=(9, 5))
bar_colors = ['#185ADB', '#0D9488', '#FFC300', '#7C3AED']
bars = ax.bar(df6['category'], df6['total_revenue'], color=bar_colors, edgecolor='none', width=0.5)
ax.bar_label(bars, fmt='$%.0f', padding=4, fontsize=11, fontweight='bold')
ax.set_ylabel('Total Revenue ($)', fontsize=12)
ax.set_title('Q6 — Revenue by Product Category', fontsize=13, fontweight='bold', pad=15)
ax.set_ylim(0, df6['total_revenue'].max() * 1.2)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x:,.0f}'))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('Q6_category_revenue.png', dpi=150, bbox_inches='tight')
plt.show()
print("Q6 done\n")

# ── Query 7 — Monthly Sales Trend ───────────────────────────
q7 = """
SELECT
    DATE_FORMAT(o.orderDate, '%b') AS month,
    MONTH(o.orderDate) AS month_num,
    ROUND(SUM(op.total)) AS monthly_sales
FROM orders o
JOIN order_payment op ON o.orderID = op.orderID
GROUP BY month_num, month
ORDER BY month_num
"""
df7 = pd.read_sql(q7, cnx)

fig, ax = plt.subplots(figsize=(11, 5))
ax.plot(df7['month'], df7['monthly_sales'], color='#185ADB', linewidth=2.5, marker='o', markersize=7)
ax.fill_between(df7['month'], df7['monthly_sales'], alpha=0.1, color='#185ADB')
for i, row in df7.iterrows():
    ax.annotate(f"${row['monthly_sales']:,.0f}", (row['month'], row['monthly_sales']),
                textcoords="offset points", xytext=(0, 10), ha='center', fontsize=10)
ax.set_title('Q7 — Monthly Sales Trend (2025)', fontsize=13, fontweight='bold', pad=15)
ax.set_ylabel('Total Sales ($)')
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x:,.0f}'))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('Q7_monthly_trend.png', dpi=150, bbox_inches='tight')
plt.show()
print("Q7 done\n")

# ── Query 8 — Top Vendors by Units Sold ─────────────────────
q8 = """
SELECT v.name AS vendor, SUM(oi.quantity) AS total_units
FROM order_item oi
JOIN product p ON oi.productID = p.productID
JOIN vendors v ON p.vendorID = v.vendorID
GROUP BY v.vendorID
ORDER BY total_units DESC
"""
df8 = pd.read_sql(q8, cnx)

fig, ax = plt.subplots(figsize=(10, 5))
bars = ax.barh(df8['vendor'][::-1], df8['total_units'][::-1], color='#7C3AED', edgecolor='none')
ax.bar_label(bars, padding=4, fontsize=10)
ax.set_xlabel('Total Units Sold')
ax.set_title('Q8 — Top Vendors by Units Sold', fontsize=13, fontweight='bold', pad=15)
ax.set_xlim(0, df8['total_units'].max() * 1.15)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('Q8_top_vendors.png', dpi=150, bbox_inches='tight')
plt.show()
print("Q8 done\n")

# ── Query 9 — Average Order Value per Store ──────────────────
q9 = """
SELECT
    COALESCE(bm.city, 'Online') AS store_name,
    ROUND(AVG(op.total), 2) AS avg_order_value,
    COUNT(o.orderID) AS num_orders
FROM orders o
JOIN order_payment op ON o.orderID = op.orderID
LEFT JOIN BM bm ON o.storeID = bm.storeID
GROUP BY o.storeID
ORDER BY avg_order_value DESC
"""
df9 = pd.read_sql(q9, cnx)

fig, ax = plt.subplots(figsize=(10, 5))
bars = ax.bar(df9['store_name'], df9['avg_order_value'],
              color='#0D9488', edgecolor='none', width=0.5)
ax.bar_label(bars, fmt='$%.2f', padding=4, fontsize=10)
ax.set_ylabel('Avg Order Value ($)')
ax.set_title('Q9 — Average Order Value per Store', fontsize=13, fontweight='bold', pad=15)
ax.set_ylim(0, df9['avg_order_value'].max() * 1.2)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x:,.0f}'))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('Q9_avg_order_value.png', dpi=150, bbox_inches='tight')
plt.show()
print("Q9 done\n")

print("=" * 50)
print("All 9 queries complete. Charts saved as PNG files.")
print("=" * 50)

cnx.close()
# Out:
# Connected!
# C:\Users\Oybek Sobirov\AppData\Local\Temp\ipykernel_1116\3981032238.py:32: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql(q1, cnx)
# Q1 done
# C:\Users\Oybek Sobirov\AppData\Local\Temp\ipykernel_1116\3981032238.py:57: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2 = pd.read_sql(q2, cnx)
# Q2 done
# C:\Users\Oybek Sobirov\AppData\Local\Temp\ipykernel_1116\3981032238.py:89: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df3 = pd.read_sql(q3, cnx)
# Q3 done
# C:\Users\Oybek Sobirov\AppData\Local\Temp\ipykernel_1116\3981032238.py:126: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df4 = pd.read_sql(q4, cnx)
# Q4 done — iPhone outsells Samsung TV in 3 out of 5 stores
# C:\Users\Oybek Sobirov\AppData\Local\Temp\ipykernel_1116\3981032238.py:159: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df5 = pd.read_sql(q5, cnx)
# Q5 done
# C:\Users\Oybek Sobirov\AppData\Local\Temp\ipykernel_1116\3981032238.py:202: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df6 = pd.read_sql(q6, cnx)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 211
#     209 ax.set_title('Q6 — Revenue by Product Category', fontsize=13, fontweight='bold', pad=15)
#     210 ax.set_ylim(0, df6['total_revenue'].max() * 1.2)
# --> 211 ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x:,.0f}'))
#     212 ax.spines['top'].set_visible(False)
#     213 ax.spines['right'].set_visible(False)
#
# NameError: name 'mticker' is not defined
